# %% [markdown]
# # Hente CSV fra SSBs API til Pandas
# ## Konjunkturtendensene (KT) prognoser

# %%
# Importerer Python pandas for å kunne lage dataframe
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# pd.read_csv() henter innholdet fra API-et og legger det i `df`.
# De norske datasettene her er semikolonseparert og med komma som desimaltegn.
# CSV i dette API-et er ikke UTF-8, så vi må angi parameter `encoding` for å få ÆØÅ riktig.

# %%
df = pd.read_csv("https://data.ssb.no/api/pxwebapi/v2/tables/12880/data?lang=no\
&valueCodes[ContentsCode]=KonsumHushold,BNP,BNPFastland,Sysselsatte,ArbLedighet,Aarslonn,KPI,KPIJAE,Boligpris,PengemRente,ImpVKroneKurs\
&valueCodes[Tid]=top(15)\
&outputFormat=csv&stub=Tid,ContentsCode\
&outputformatparams=usetexts", encoding = "ISO-8859-1" )

# %% [markdown]
# Sjekker at datatypen Pandas dataframe

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 3 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   år                                                              165 non-null    int64
#  1   statistikkvariabel                                              165 non-null    str
#  2   12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,  165 non-null    float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 7.3 KB

# %% [markdown]
# Viser 12 første linjer av datasettet

# %%
df.head(12)
# Out:
#       år              statistikkvariabel  \
# 0   2015       Konsum i husholdninger mv
# 1   2015     Bruttonasjonalprodukt (BNP)
# 2   2015             BNP Fastlands-Norge
# 3   2015            Sysselsatte personer
# 4   2015     Arbeidsledighetsrate (nivå)
# 5   2015                         Årslønn
# 6   2015        Konsumprisindeksen (KPI)
# 7   2015                         KPI-JAE
# 8   2015                       Boligpris
# 9   2015        Pengemarkedsrente (nivå)
# 10  2015  Importveid kronekurs (44 land)
# 11  2016       Konsum i husholdninger mv
#
#     12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,
# 0                                                 3.7
# 1                                                 2.0
# 2                                                 1.7
# 3                                                 0.4
# 4                                                 4.5
# 5                                                 2.8
# 6                                                 2.1
# 7                                                 2.7
# 8                                                 6.1
# 9                                                 1.3
# 10                                               10.5
# 11                                                2.1

# %% [markdown]
# Evt. enkel endring til datoformat. Ikke strengt nødvendig.

# %%
df['år'] = pd.to_datetime(df['år'], format='%Y', errors='coerce').dt.year

# %%
df
# Out:
#        år              statistikkvariabel  \
# 0    2015       Konsum i husholdninger mv
# 1    2015     Bruttonasjonalprodukt (BNP)
# 2    2015             BNP Fastlands-Norge
# 3    2015            Sysselsatte personer
# 4    2015     Arbeidsledighetsrate (nivå)
# ..    ...                             ...
# 160  2029        Konsumprisindeksen (KPI)
# 161  2029                         KPI-JAE
# 162  2029                       Boligpris
# 163  2029        Pengemarkedsrente (nivå)
# 164  2029  Importveid kronekurs (44 land)
#
#      12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,
# 0                                                  3.7
# 1                                                  2.0
# 2                                                  1.7
# 3                                                  0.4
# 4                                                  4.5
# ..                                                 ...
# 160                                                2.1
# 161                                                2.1
# 162                                                4.6
# 163                                                3.8
# 164                                                0.0
#
# [165 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 3 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   år                                                              165 non-null    int32
#  1   statistikkvariabel                                              165 non-null    str
#  2   12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,  165 non-null    float64
# dtypes: float64(1), int32(1), str(1)
# memory usage: 6.6 KB

# %% [markdown]
# Lager linjediagrammer med Pandas plot. Vi angir x og y aksen og grupperer med .groupby.
# Vi ønsker ikke å få alfabetisk sortering.

# %% [markdown]
# ### Alternativt- iterere

# %%
for group_name, group_data in df.groupby('statistikkvariabel', sort=False):
    group_data.plot(x='år', figsize=(6, 3), color ='g')
    plt.title("Konjunkturtendensene: " + group_name)
    plt.legend('', frameon=False)
    plt.show()

# %% [markdown]
# For å få alle linjene i en figur i Pandas plot er det best å pivotere tabellen. Oppretter derfor en ny dataframe df2, med år som index.

# %%
df2 = df.pivot(index='år', 
               columns='statistikkvariabel', 
               values='12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,'
              )

# %% [markdown]
# df2 er 'wide' i stedet for 'long'

# %%
df2
# Out:
# statistikkvariabel  Arbeidsledighetsrate (nivå)  BNP Fastlands-Norge  \
# år
# 2015                                        4.5                  1.7
# 2016                                        4.7                  1.0
# 2017                                        4.2                  2.4
# 2018                                        3.8                  2.1
# 2019                                        3.7                  2.7
# 2020                                        4.6                 -2.7
# 2021                                        4.4                  4.7
# 2022                                        3.2                  5.2
# 2023                                        3.6                  0.9
# 2024                                        4.0                  0.6
# 2025                                        4.5                  1.7
# 2026                                        4.6                  1.4
# 2027                                        4.4                  2.1
# 2028                                        4.3                  1.5
# 2029                                        4.2                  1.9
#
# statistikkvariabel  Boligpris  Bruttonasjonalprodukt (BNP)  \
# år
# 2015                      6.1                          2.0
# 2016                      7.0                          1.3
# 2017                      5.0                          2.7
# 2018                      1.4                          1.1
# 2019                      2.5                          1.5
# 2020                      4.3                         -1.4
# 2021                     10.5                          4.1
# 2022                      5.2                          4.1
# 2023                     -0.5                          0.4
# 2024                      2.7                          1.4
# 2025                      5.5                          1.1
# 2026                      3.1                          1.4
# 2027                      3.5                          1.2
# 2028                      4.0                          0.5
# 2029                      4.6                          0.4
#
# statistikkvariabel  Importveid kronekurs (44 land)  KPI-JAE  \
# år
# 2015                                          10.5      2.7
# 2016                                           1.8      3.0
# 2017                                          -0.8      1.4
# 2018                                           0.1      1.6
# 2019                                           2.9      2.2
# 2020                                           6.7      3.0
# 2021                                          -5.3      1.7
# 2022                                           1.2      3.9
# 2023                                           8.5      6.2
# 2024                                           0.8      3.7
# 2025                                          -0.6      3.1
# 2026                                          -6.2      3.0
# 2027                                          -2.2      2.5
# 2028                                           0.0      2.3
# 2029                                           0.0      2.1
#
# statistikkvariabel  Konsum i husholdninger mv  Konsumprisindeksen (KPI)  \
# år
# 2015                                      3.7                       2.1
# 2016                                      2.1                       3.6
# 2017                                      3.1                       1.8
# 2018                                      2.7                       2.7
# 2019                                      1.9                       2.2
# 2020                                     -4.3                       1.3
# 2021                                      6.1                       3.5
# 2022                                      7.2                       5.8
# 2023                                     -1.0                       5.5
# 2024                                      1.3                       3.1
# 2025                                      2.6                       3.1
# 2026                                      1.4                       3.2
# 2027                                      2.1                       2.5
# 2028                                      2.4                       2.2
# 2029                                      2.9                       2.1
#
# statistikkvariabel  Pengemarkedsrente (nivå)  Sysselsatte personer  Årslønn
# år
# 2015                                     1.3                   0.4      2.8
# 2016                                     1.1                   0.3      1.7
# 2017                                     0.9                   1.2      2.3
# 2018                                     1.1                   1.6      2.8
# 2019                                     1.6                   1.6      3.5
# 2020                                     0.7                  -1.5      3.1
# 2021                                     0.5                   1.1      3.5
# 2022                                     2.1                   3.8      4.3
# 2023                                     4.2                   1.2      5.2
# 2024                                     4.7                   0.7      5.6
# 2025                                     4.4                   0.7      4.9
# 2026                                     4.5                   0.5      4.3
# 2027                                     4.6                   0.6      3.7
# 2028                                     4.0                   0.6      3.4
# 2029                                     3.8                   0.5      3.0

# %% [markdown]
# Pandas plot av df2. Angir størrelse, datamarkør og tittel som parametre.

# %%
df2.plot(figsize=(12, 20), subplots = [('Bruttonasjonalprodukt (BNP)', 'BNP Fastlands-Norge', 'Konsum i husholdninger mv', 'Konsumprisindeksen (KPI)', 'KPI-JAE'),('Arbeidsledighetsrate (nivå)', 'Sysselsatte personer', 'Årslønn', 'Boligpris')])
# Out:
# array([<Axes: xlabel='år'>, <Axes: xlabel='år'>, <Axes: xlabel='år'>,
#        <Axes: xlabel='år'>], dtype=object)

# %%
df2.plot(figsize=(12, 12), marker='v', title='Konjunkturtendensene, inkl. prognoser 4 år')
# Out:
# <Axes: title={'center': 'Konjunkturtendensene, inkl. prognoser 4 år'}, xlabel='år'>

# %% [markdown]
# ### Plot med et annet verktøy [Plotly](https://plotly.com/python/). Her bruker jeg det enklere "Plotly express"

# %%
# !pip install plotly
import plotly.express as px  # px her er standard angivelse for Plotly express. Har ikke noe å gjøre med Statistikkbank px

# %%
fig = px.line(df, x='år', y='12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,')

# %% [markdown]
# Merk at her er input den opprinnelige df, som er 'long'. Det blir ikke bra, uten gruppering.

# %%
fig.show()

# %% [markdown]
# Plotly Express har argumentet 'line_group', for gruppering. Her legger jeg også på tittel og tekst til y-aksen.

# %%
px.line(df, x=('år'), y='12880: Makroøkonomiske hovedstørrelser. Regnskap og prognoser,', 
              color='statistikkvariabel', 
              line_group='statistikkvariabel', 
              title='Konjunkturtendensene, utvalgte prognoser 4 år', 
              )

# %% [markdown]
# ### Med Plotly Express wide

# %% [markdown]
# Plotly Express støtter fra 2020 også 'wide'. Nå vi kan lage samme plot med df2 som er 'wide'

# %%
df2.head(2)
# Out:
# statistikkvariabel  Arbeidsledighetsrate (nivå)  BNP Fastlands-Norge  \
# år
# 2015                                        4.5                  1.7
# 2016                                        4.7                  1.0
#
# statistikkvariabel  Boligpris  Bruttonasjonalprodukt (BNP)  \
# år
# 2015                      6.1                          2.0
# 2016                      7.0                          1.3
#
# statistikkvariabel  Importveid kronekurs (44 land)  KPI-JAE  \
# år
# 2015                                          10.5      2.7
# 2016                                           1.8      3.0
#
# statistikkvariabel  Konsum i husholdninger mv  Konsumprisindeksen (KPI)  \
# år
# 2015                                      3.7                       2.1
# 2016                                      2.1                       3.6
#
# statistikkvariabel  Pengemarkedsrente (nivå)  Sysselsatte personer  Årslønn
# år
# 2015                                     1.3                   0.4      2.8
# 2016                                     1.1                   0.3      1.7

# %%
fig2 = px.line(df2, x=df2.index, y=df2.columns, line_group='statistikkvariabel')

# %%
fig2.show()

# %% [markdown]
# Det er mulig å sette Plotly som Pandas .plot, istedet for Matplotlib

# %%
pd.options.plotting.backend = "plotly"

# %% [markdown]
# Da fungerer plot av df2 uten parametre

# %%
df2.plot()

# %% [markdown]
# Dessverre mister en da også fleksibiliteten, siden vi ikke kan bruke Plotly sin egen funksjonalitet.
#
# Her er et eksempel med Plotly facet plot.

# %%
fig3 = px.area(df2, 
               facet_col='statistikkvariabel', 
               facet_col_wrap=3, 
               template='none',
               height = 900,
               title = "Konjunkturtendensene - Prognoser for Norge", 
               labels = dict(value ="% endring")).update_layout(showlegend= False)

# %%
fig3.show()

# %% [markdown]
# Det blir mer oversiktlig om vi kun viser statistikkvariabelens tekst. Se [Customizing subplot title figures](https://plotly.com/python/facet-plots/#customizing-subplot-figure-titles)

# %%
fig3.for_each_annotation(lambda a: a.update(text=a.text.split("=")[-1]))

# %% [markdown]
# ## Hele KT-tabellen fra og med 2014

# %%
kt_tab_url = "https://data.ssb.no/api/pxwebapi/v2/tables/12880/data?lang=no&valueCodes[ContentsCode]=KonsumHushold,KonsumOffentl,BtoInvFastReal,BtoInvUtvRor,BtoInvFastlNorge,BtoInvNaring,BtoInvBolig,BtoInvOffForv,EtterspFastland,Eksport,EkspTradVarer,EkspOljeGass,Import,ImpTradVarer,BNP,BNPFastland,BNPIndustri,BNPLopPriser,TimeverkFastland,Sysselsatte,ArbStyrke,Yrkesandel,ArbLedighet,Aarslonn,KPI,KPIJAE,EksportprisTrad,ImportprisTrad,Boligpris,HusholdDisp,HusholdSpare,PengemRente,UtlaanRente,Realrente,ImpVKroneKurs,NOKperEuro,Driftsbalanse,DriftsbalanseBNP,EksportMarked,KonsumprisEuro,PengemRenteEuro,OljePrisDollar,OljePrisKr&valueCodes[Tid]=from(2014)&heading=Tid&outputformat=csv&outputformatparams=usetexts"

# %% [markdown]
# Vi henter alle variabler fra og med 2014. Det sentrale er `[Tid]=from(2014)&heading=Tid&outputformat=csv&outputformatparams=usetexts`

# %%
kt_tab = pd.read_csv(kt_tab_url, encoding = "ISO-8859-1")

# %% [markdown]
# I "Konjunkturtendenser" er de siste 4 årene prognoser.
#
# Identifiser de siste 4 kolonnene.

# %%
last_4_cols = kt_tab.columns[-4:]

# %% [markdown]
# Sett **blå farge på prognosene**. Ved "styling" må jeg også eksplisitt sette antall desimaler som vises.

# %%
styled_kt_tab = kt_tab.style.format(precision=1).set_properties(
    subset=last_4_cols,
    color='blue'
    )

# %%
styled_kt_tab
# Out:
# <style type="text/css">
# #T_84bec_row0_col13, #T_84bec_row0_col14, #T_84bec_row0_col15, #T_84bec_row0_col16, #T_84bec_row1_col13, #T_84bec_row1_col14, #T_84bec_row1_col15, #T_84bec_row1_col16, #T_84bec_row2_col13, #T_84bec_row2_col14, #T_84bec_row2_col15, #T_84bec_row2_col16, #T_84bec_row3_col13, #T_84bec_row3_col14, #T_84bec_row3_col15, #T_84bec_row3_col16, #T_84bec_row4_col13, #T_84bec_row4_col14, #T_84bec_row4_col15, #T_84bec_row4_col16, #T_84bec_row5_col13, #T_84bec_row5_col14, #T_84bec_row5_col15, #T_84bec_row5_col16, #T_84bec_row6_col13, #T_84bec_row6_col14, #T_84bec_row6_col15, #T_84bec_row6_col16, #T_84bec_row7_col13, #T_84bec_row7_col14, #T_84bec_row7_col15, #T_84bec_row7_col16, #T_84bec_row8_col13, #T_84bec_row8_col14, #T_84bec_row8_col15, #T_84bec_row8_col16, #T_84bec_row9_col13, #T_84bec_row9_col14, #T_84bec_row9_col15, #T_84bec_row9_col16, #T_84bec_row10_col13, #T_84bec_row10_col14, #T_84bec_row10_col15, #T_84bec_row10_col16, #T_84bec_row11_col13, #T_84bec_row11_col14, #T_84bec_row11_col15, #T_84bec_row11_col16, #T_84bec_row12_col13, #T_84bec_row12_col14, #T_84bec_row12_col15, #T_84bec_row12_col16, #T_84bec_row13_col13, #T_84bec_row13_col14, #T_84bec_row13_col15, #T_84bec_row13_col16, #T_84bec_row14_col13, #T_84bec_row14_col14, #T_84bec_row14_col15, #T_84bec_row14_col16, #T_84bec_row15_col13, #T_84bec_row15_col14, #T_84bec_row15_col15, #T_84bec_row15_col16, #T_84bec_row16_col13, #T_84bec_row16_col14, #T_84bec_row16_col15, #T_84bec_row16_col16, #T_84bec_row17_col13, #T_84bec_row17_col14, #T_84bec_row17_col15, #T_84bec_row17_col16, #T_84bec_row18_col13, #T_84bec_row18_col14, #T_84bec_row18_col15, #T_84bec_row18_col16, #T_84bec_row19_col13, #T_84bec_row19_col14, #T_84bec_row19_col15, #T_84bec_row19_col16, #T_84bec_row20_col13, #T_84bec_row20_col14, #T_84bec_row20_col15, #T_84bec_row20_col16, #T_84bec_row21_col13, #T_84bec_row21_col14, #T_84bec_row21_col15, #T_84bec_row21_col16, #T_84bec_row22_col13, #T_84bec_row22_col14, #T_84bec_row22_col15, #T_84bec_row22_col16, #T_84bec_row23_col13, #T_84bec_row23_col14, #T_84bec_row23_col15, #T_84bec_row23_col16, #T_84bec_row24_col13, #T_84bec_row24_col14, #T_84bec_row24_col15, #T_84bec_row24_col16, #T_84bec_row25_col13, #T_84bec_row25_col14, #T_84bec_row25_col15, #T_84bec_row25_col16, #T_84bec_row26_col13, #T_84bec_row26_col14, #T_84bec_row26_col15, #T_84bec_row26_col16, #T_84bec_row27_col13, #T_84bec_row27_col14, #T_84bec_row27_col15, #T_84bec_row27_col16, #T_84bec_row28_col13, #T_84bec_row28_col14, #T_84bec_row28_col15, #T_84bec_row28_col16, #T_84bec_row29_col13, #T_84bec_row29_col14, #T_84bec_row29_col15, #T_84bec_row29_col16, #T_84bec_row30_col13, #T_84bec_row30_col14, #T_84bec_row30_col15, #T_84bec_row30_col16, #T_84bec_row31_col13, #T_84bec_row31_col14, #T_84bec_row31_col15, #T_84bec_row31_col16, #T_84bec_row32_col13, #T_84bec_row32_col14, #T_84bec_row32_col15, #T_84bec_row32_col16, #T_84bec_row33_col13, #T_84bec_row33_col14, #T_84bec_row33_col15, #T_84bec_row33_col16, #T_84bec_row34_col13, #T_84bec_row34_col14, #T_84bec_row34_col15, #T_84bec_row34_col16, #T_84bec_row35_col13, #T_84bec_row35_col14, #T_84bec_row35_col15, #T_84bec_row35_col16, #T_84bec_row36_col13, #T_84bec_row36_col14, #T_84bec_row36_col15, #T_84bec_row36_col16, #T_84bec_row37_col13, #T_84bec_row37_col14, #T_84bec_row37_col15, #T_84bec_row37_col16, #T_84bec_row38_col13, #T_84bec_row38_col14, #T_84bec_row38_col15, #T_84bec_row38_col16, #T_84bec_row39_col13, #T_84bec_row39_col14, #T_84bec_row39_col15, #T_84bec_row39_col16, #T_84bec_row40_col13, #T_84bec_row40_col14, #T_84bec_row40_col15, #T_84bec_row40_col16, #T_84bec_row41_col13, #T_84bec_row41_col14, #T_84bec_row41_col15, #T_84bec_row41_col16, #T_84bec_row42_col13, #T_84bec_row42_col14, #T_84bec_row42_col15, #T_84bec_row42_col16 {
#   color: blue;
# }
# </style>
# <table id="T_84bec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84bec_level0_col0" class="col_heading level0 col0" >statistikkvariabel</th>
#       <th id="T_84bec_level0_col1" class="col_heading level0 col1" >2014</th>
#       <th id="T_84bec_level0_col2" class="col_heading level0 col2" >2015</th>
#       <th id="T_84bec_level0_col3" class="col_heading level0 col3" >2016</th>
#       <th id="T_84bec_level0_col4" class="col_heading level0 col4" >2017</th>
#       <th id="T_84bec_level0_col5" class="col_heading level0 col5" >2018</th>
#       <th id="T_84bec_level0_col6" class="col_heading level0 col6" >2019</th>
#       <th id="T_84bec_level0_col7" class="col_heading level0 col7" >2020</th>
#       <th id="T_84bec_level0_col8" class="col_heading level0 col8" >2021</th>
#       <th id="T_84bec_level0_col9" class="col_heading level0 col9" >2022</th>
#       <th id="T_84bec_level0_col10" class="col_heading level0 col10" >2023</th>
#       <th id="T_84bec_level0_col11" class="col_heading level0 col11" >2024</th>
#       <th id="T_84bec_level0_col12" class="col_heading level0 col12" >2025</th>
#       <th id="T_84bec_level0_col13" class="col_heading level0 col13" >2026</th>
#       <th id="T_84bec_level0_col14" class="col_heading level0 col14" >2027</th>
#       <th id="T_84bec_level0_col15" class="col_heading level0 col15" >2028</th>
#       <th id="T_84bec_level0_col16" class="col_heading level0 col16" >2029</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84bec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_84bec_row0_col0" class="data row0 col0" >Konsum i husholdninger mv</td>
#       <td id="T_84bec_row0_col1" class="data row0 col1" >2.9</td>
#       <td id="T_84bec_row0_col2" class="data row0 col2" >3.7</td>
#       <td id="T_84bec_row0_col3" class="data row0 col3" >2.1</td>
#       <td id="T_84bec_row0_col4" class="data row0 col4" >3.1</td>
#       <td id="T_84bec_row0_col5" class="data row0 col5" >2.7</td>
#       <td id="T_84bec_row0_col6" class="data row0 col6" >1.9</td>
#       <td id="T_84bec_row0_col7" class="data row0 col7" >-4.3</td>
#       <td id="T_84bec_row0_col8" class="data row0 col8" >6.1</td>
#       <td id="T_84bec_row0_col9" class="data row0 col9" >7.2</td>
#       <td id="T_84bec_row0_col10" class="data row0 col10" >-1.0</td>
#       <td id="T_84bec_row0_col11" class="data row0 col11" >1.3</td>
#       <td id="T_84bec_row0_col12" class="data row0 col12" >2.6</td>
#       <td id="T_84bec_row0_col13" class="data row0 col13" >1.4</td>
#       <td id="T_84bec_row0_col14" class="data row0 col14" >2.1</td>
#       <td id="T_84bec_row0_col15" class="data row0 col15" >2.4</td>
#       <td id="T_84bec_row0_col16" class="data row0 col16" >2.9</td>
#     </tr>
#     <tr>
#       <th id="T_84bec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_84bec_row1_col0" class="data row1 col0" >Konsum i offentlig forvaltning</td>
#       <td id="T_84bec_row1_col1" class="data row1 col1" >2.5</td>
#       <td id="T_84bec_row1_col2" class="data row1 col2" >2.5</td>
#       <td id="T_84bec_row1_col3" class="data row1 col3" >2.3</td>
#       <td id="T_84bec_row1_col4" class="data row1 col4" >2.0</td>
#       <td id="T_84bec_row1_col5" class="data row1 col5" >0.6</td>
#       <td id="T_84bec_row1_col6" class="data row1 col6" >1.0</td>
#       <td id="T_84bec_row1_col7" class="data row1 col7" >-0.2</td>
#       <td id="T_84bec_row1_col8" class="data row1 col8" >3.6</td>
#       <td id="T_84bec_row1_col9" class="data row1 col9" >3.0</td>
#       <td id="T_84bec_row1_col10" class="data row1 col10" >4.4</td>
#       <td id="T_84bec_row1_col11" class="data row1 col11" >1.7</td>
#       <td id="T_84bec_row1_col12" class="data row1 col12" >2.4</td>
#       <td id="T_84bec_row1_col13" class="data row1 col13" >2.3</td>
#       <td id="T_84bec_row1_col14" class="data row1 col14" >1.9</td>
#       <td id="T_84bec_row1_col15" class="data row1 col15" >1.1</td>
#       <td id="T_84bec_row1_col16" class="data row1 col16" >1.5</td>
#     </tr>
#     <tr>
#       <th id="T_84bec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_84bec_row2_col0" class="data row2 col0" >Bruttoinvestering i fast realkapital</td>
#       <td id="T_84bec_row2_col1" class="d

# %% [markdown]
# Et tips til slutt: Prøv å lage ditt eget datasett i stedet. Du kan også benytte det rikere JSON-stat-formatet og det tilhørende biblioteket pyjstat framfor CSV.
